# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
#
# Author: [Yury Kashnitsky](https://yorko.github.io). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center> Topic 1. Exploratory data analysis with Pandas
# ## <center>Practice. Analyzing "Titanic" passengers
#
# **Fill in the missing code ("You code here") and choose answers in a [web-form](https://docs.google.com/forms/d/16EfhpDGPrREry0gfDQdRPjoiQX9IumaL2mPR0rcj19k/edit).**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'
pd.set_option("display.precision", 2)

# %% [markdown]
# **Read data into a Pandas DataFrame**

# %%
data = pd.read_csv('titanic_train.csv',
                  index_col='PassengerId')

# %% [markdown]
# **First 5 rows**

# %%
data.head(15)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
#
#              SibSp  Parch            Ticket   Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.25   NaN        S
# 2                1      0          PC 17599  71.28   C85        C
# 3                0      0  STON/O2. 3101282   7.92   NaN        S
# 4                1      0            113803  53.10  C123        S
# 5                0      0            373450   8.05   NaN        S
# 6                0      0            330877   8.46   NaN        Q
# 7                0      0             17463  51.86   E46        S
# 8                3      1            349909  21.07   NaN        S
# 9                0      2            347742  11.13   NaN        S
# 10               1      0            237736  30.07   NaN        C
# 11               1      1           PP 9549  16.70    G6        S
# 12               0      0            113783  26.55  C103        S
# 13               0      0         A/5. 2151   8.05   NaN        S
# 14               1      5            347082  31.27   NaN        S
# 15               0      0            350406   7.85   NaN        S

# %%
data.describe()
# Out:
#        Survived  Pclass     Age   SibSp   Parch    Fare
# count    891.00  891.00  714.00  891.00  891.00  891.00
# mean       0.38    2.31   29.70    0.52    0.38   32.20
# std        0.49    0.84   14.53    1.10    0.81   49.69
# min        0.00    1.00    0.42    0.00    0.00    0.00
# 25%        0.00    2.00   20.12    0.00    0.00    7.91
# 50%        0.00    3.00   28.00    0.00    0.00   14.45
# 75%        1.00    3.00   38.00    1.00    0.00   31.00
# max        1.00    3.00   80.00    8.00    6.00  512.33

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Let's select those passengers who embarked in Cherbourg (Embarked=C) and paid > 200 pounds for their ticker (fare > 200).**
#
# Make sure you understand how actually this construction works.

# %%
c_embarked = data[(data['Embarked'] == 'C') & (data.Fare > 200)]
c_embarked.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket    Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.52          B58 B60        C
# 259              0      0  PC 17755  512.33              NaN        C
# 300              0      1  PC 17558  247.52          B58 B60        C
# 312              2      2  PC 17608  262.38  B57 B59 B63 B66        C
# 378              0      2    113503  211.50              C82        C

# %% [markdown]
# **We can sort these people by Fare in descending order.**

# %%
data[(data['Embarked'] == 'C') & 
     (data['Fare'] > 200)].sort_values(by='Fare',
                               ascending=False).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket    Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.33              NaN        C
# 680          36.0      0      1  PC 17755  512.33      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.33             B101        C
# 312          18.0      2      2  PC 17608  262.38  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.38  B57 B59 B63 B66        C

# %%
c_embarked.sort_values(by='Fare',ascending=False).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket    Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.33              NaN        C
# 680          36.0      0      1  PC 17755  512.33      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.33             B101        C
# 312          18.0      2      2  PC 17608  262.38  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.38  B57 B59 B63 B66        C

# %% [markdown]
# **Let's create a new feature.**

# %%
def age_category(age):
    '''
    < 30 -> 1
    >= 30, <55 -> 2
    >= 55 -> 3
    '''
    if age < 30:
        return 1
    elif age < 55:
        return 2
    elif age >= 55:
        return 3

# %%
age_categories = [age_category(age) for age in data.Age]
data['Age_category'] = age_categories

# %%
# Out:
# 577
# 314

# %% [markdown]
# **Another way is to do it with `apply`.**

# %%
data['Age_category'] = data['Age'].apply(age_category)

# %% [markdown]
# **1. How many men/women were there onboard?**
# - 412 men and 479 women
# - 314 men and 577 women
# - 479 men and 412 women
# - 577 men and 314 women

# %%
print(data['Sex'].value_counts()
    )

males = data[data['Sex'] == 'male']
print(males['Sex'].count())
females = data[data['Sex'] == 'female']
print(females['Sex'].count())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 577
# 314

# %%
data.groupby('Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %% [markdown]
# **2. Print the distribution of the `Pclass` feature. Then the same, but for men and women separately. How many men from second class were there onboard?**
# - 104
# - 108
# - 112
# - 125

# %%
data['Pclass'].value_counts()

clas2 = data[data['Pclass']==2]
clas2.head()


clas2['Sex'].value_counts()
# Out:
# male      108
# female     76
# Name: Sex, dtype: int64

# %%
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# **3. What are median and standard deviation of `Fare`?. Round to two decimals.**
# - median is  14.45, standard deviation is 49.69
# - median is 15.1, standard deviation is 12.15
# - median is 13.15, standard deviation is 35.3
# - median is  17.43, standard deviation is 39.1

# %%
# You code here
data['Fare'].describe()

print(round(data.Fare.median(),2))
print(round(data.Fare.std(),2))
# Out:
# 14.45
# 49.69

# %% [markdown]
# **4. Is that true that the mean age of survived people is higher than that of passengers who eventually died?**
# - Yes
# - No

# %%
# You code here
print(data[data['Survived']==1].Age.mean())
print(data[data['Survived']==0].Age.mean())

#survival - Survival (0 = No; 1 = Yes)
# Out:
# 28.343689655172415
# 30.62617924528302

# %% [markdown]
# **5. Is that true that passengers younger than 30 y.o. survived more frequently than those older than 60 y.o.? What are shares of survived people among young and old people?**
# - 22.7% among young and 40.6% among old
# - 40.6% among young and 22.7% among old
# - 35.3% among young and 27.4% among old
# - 27.4% among young and  35.3% among old

# %%
# You code here
Survived = data[data['Survived']==1]



YoungS = Survived[Survived['Age'] < 30]


OldS = Survived[Survived['Age']  > 60]


young_rate = YoungS.Age.count() / data[data['Age']<30].Age.count()
print(round(young_rate,3)*100)

old_rate = OldS.Age.count() / data[data['Age']>60].Age.count()
print(round(old_rate,3)*100)
# Out:
# 40.6
# 22.7

# %% [markdown]
# **6. Is that true that women survived more frequently than men? What are shares of survived people among men and women?**
# - 30.2% among men and 46.2% among women
# - 35.7% among men and 74.2% among women
# - 21.1% among men and 46.2% among women
# - 18.9% among men and 74.2% among women

# %%
# You code here
Survived = data[data['Survived']==1]

maleS = Survived[Survived['Sex'] == 'male']


femaleS = Survived[Survived['Sex'] == 'female']

male_rate = maleS.Sex.count() / data[data['Sex']=='male'].Sex.count()
print(round(male_rate,3)*100)

female_rate = femaleS.Sex.count() / data[data['Sex']=='female'].Sex.count()
print(round(female_rate,3)*100)
# Out:
# 18.9
# 74.2

# %% [markdown]
# **7. What's the most popular first name among male passengers?**
# - Charles
# - Thomas
# - William
# - John

# %%
# You code here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-b26296e1fd41> in <module>
#       1 # You code here
# ----> 2 data.groupby('Name'[3]).size()
#
# ~\Anaconda3\envs\Ana1\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\envs\Ana1\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\envs\Ana1\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~\Anaconda3\envs\Ana1\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'e'

# %% [markdown]
# **8. How is average age for men/women dependent on `Pclass`? Choose all correct statements:**
# - On average, men of 1 class are older than 40
# - On average, women of 1 class are older than 40
# - Men of all classes are on average older than women of the same class
# - On average, passengers ofthe first class are older than those of the 2nd class who are older than passengers of the 3rd class

# %%
# You code here

# %% [markdown]
# ## Useful resources
# * The same notebook as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-practice-analyzing-titanic-passengers) with a [solution](https://www.kaggle.com/kashnitsky/topic-1-practice-solution)
# * Topic 1 "Exploratory Data Analysis with Pandas" as a [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
# * Main course [site](https://mlcourse.ai), [course repo](https://github.com/Yorko/mlcourse.ai), and YouTube [channel](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
